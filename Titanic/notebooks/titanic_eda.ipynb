# %% [markdown]
# # Titanic Sinking
# The sinking of the Titanic is one of the most infamous shipwrecks in history.
#
# On April 15, 1912, during her maiden voyage, the widely considered “unsinkable” RMS Titanic sank after colliding with an iceberg. Unfortunately, there weren’t enough lifeboats for everyone on board, resulting in the death of 1502 out of 2224 passengers and crew.
#
# While there was some element of luck involved in surviving, it seems some groups of people were more likely to survive than others.
#
# In this challenge, we ask you to build a predictive model that answers the question: “what sorts of people were more likely to survive?” using passenger data (ie name, age, gender, socio-economic class, etc).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv('../data/titanic.csv')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  adult_male deck  \
# 0           0       3    male  22.0      1      0   7.2500        True  NaN
# 1           1       1  female  38.0      1      0  71.2833       False    C
# 2           1       3  female  26.0      0      0   7.9250       False  NaN
# 3           1       1  female  35.0      1      0  53.1000       False    C
# 4           0       3    male  35.0      0      0   8.0500        True  NaN
# ..        ...     ...     ...   ...    ...    ...      ...         ...  ...
# 886         0       2    male  27.0      0      0  13.0000        True  NaN
# 887         1       1  female  19.0      0      0  30.0000       False    B
# 888         0       3  female   NaN      1      2  23.4500       False  NaN
# 889         1       1    male  26.0      0      0  30.0000        True    C
# 890         0       3    male  32.0      0      0   7.7500        True  NaN
#
# ...

# %% [markdown]
# # Information about the Data
# Here are some additional insights regarding the data that is within the dataset.
# - Passangerid: The ID of the passenger
# - Survived: Whether the passenger survived or not
# - Pclass: Ticket class, either 1st, 2nd, or 3rd
# - Name: Name of the passenger
# - Sex: Gender
# - Age: Age in years
# - SibSp: Number of siblings and/or spouses aboard the titanic
# - Parch: Number of parents and/or children aboard the titanic
# - Ticket: ticket number
# - Fare: Passanger fare

# %%
sns.countplot(data=titanic, x='survived')
plt.title('Survived Counts')
plt.xlabel('Survived')
plt.ylabel('Count')

plt.xticks(ticks=[0, 1], labels=['No', 'Yes'])
# Out:
# ([<matplotlib.axis.XTick at 0x147254910>,
# ...
#  [Text(0, 0, 'No'), Text(1, 0, 'Yes')])

# %%
sns.countplot(titanic, x='survived',
                hue='sex')

plt.xticks(ticks=[0, 1], labels=['No', 'Yes'])
# Out:
# ([<matplotlib.axis.XTick at 0x1509bb150>,
# ...
#  [Text(0, 0, 'No'), Text(1, 0, 'Yes')])

# %%
sns.countplot(titanic, x='pclass',
                hue='survived'
)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='count'>

# %%
sns.barplot(titanic, x='pclass',
            y='fare')
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %%
sns.histplot(titanic, x='pclass',
            hue='survived'
            )
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='Count'>

# %%
sns.countplot(titanic,
                x='adult_male',
                hue='survived')
plt.legend(title='Survived', labels=['No', 'Yes'])

# %%
sns.countplot(titanic,
                x='deck',
                hue='survived')
plt.legend(title='Survived', labels=['No', 'Yes'])

# %%
sns.countplot(titanic,
                x='sibsp',
                hue='survived')

plt.legend(title='Survived', labels=['No', 'Yes'])

# %%
sns.countplot(titanic,
                x='parch',
                hue='survived')

plt.legend(title='Survived', labels=['No', 'Yes'])

# %%
sns.countplot(titanic,
                x='alone',
                hue='survived')

plt.legend(title='Survived', labels=['No', 'Yes'])

# %%
sns.scatterplot(titanic,
                x='age',
                y='fare',
                hue='survived')

plt.legend(title='Survived', labels=['No', 'Yes'])
